# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (10,5)
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Read data
df = pd.read_csv('https://raw.githubusercontent.com/rutikhatim/Assignment/main/Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
#Correlation analysis

# %%
sns.scatterplot(x=df['YearsExperience'],y=df['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Import statsmodels

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('Salary~YearsExperience',data=df).fit()
model

# %%
#Model parameters
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
#Print p value
model.pvalues
# Out:
# Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %%
#r2 value
model.rsquared, model.rsquared_adj
# Out:
# (0.9569566641435086, 0.9554194021486339)

# %% [markdown]
# # Prediction for new data

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x_test = pd.DataFrame({
    'YearsExperience' : [4,8.2,9,6.2,3.8]
    
})
x_test
# Out:
#    YearsExperience
# 0              4.0
# 1              8.2
# 2              9.0
# 3              6.2
# 4              3.8

# %%
model.predict(x_test)
# Out:
# 0     63592.049484
# 1    103281.891235
# 2    110841.861092
# 3     84381.966592
# 4     61702.057020
# dtype: float64
